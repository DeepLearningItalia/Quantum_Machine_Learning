# %% [markdown]
# # **FINAL EXAM**

# %% [markdown]
# Dear student,
#
# congratulations for reaching this point of your path in Quantum Machine Learning, I hope it has been an interesting journey.
#
# You are in the very last step before achieving the QML diploma by Deeplearning ITALIA.
# In this final exam you will be asked to do the following:
# 1.   Take the Wisconsin Breast Cancer dataset
# 2.   Split TR: 70%, TS: 30%
# 3.   Modify the Quantum Boltzmann Machine we saw during the lectures and turn it into a Classifier
# 4.   Classify the presence or absence of breast cancer
# 5.   Apply the Feature Selection we also saw during the lectures
# 6.   Interpret the results
#
# For this experiment you will be using:
# -    Ocean SDK by D-Wave
# -    Python
# -    D-Wave Sys architecture
# If you run out of time in the cloud you can switch the sampler to the simulated annealing.
#
# As output I expect:
# -    Classification report (as per scikit-learn)
# -    ROC Curve plot
# -    Matthews Correlation Coefficient metric
#
# The reference for the project are all linked in the course slides.
#
# Have fun and good luck!

# %%
######################################
########## IMPORT LIBRARIES ##########
######################################

# %%
######################################
########### IMPORT DATASET ###########
######################################

# %%
######################################
############ CREATE SPLIT ############
######################################

# %%
######################################
############# QRBM MODEL #############
######################################

# %%
######################################
########## FEATURE SELECTION #########
######################################

# %%
######################################
####### CLASSIFICATION REPORT ########
######################################

# %%
######################################
############## PLOT ROC ##############
######################################
